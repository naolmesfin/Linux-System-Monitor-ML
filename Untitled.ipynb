# %%
import pandas as pd
import matplotlib.pyplot as plt

# Since the file is in the same folder, this will now work!
df = pd.read_csv('system_logs.csv')

# Look at the first few rows to make sure it's correct
print(df.head())

# Create your plot
df.plot(x='timestamp', y='cpu_usage', figsize=(10,5), title='Linux System Load')
plt.show()
# Out:
#              timestamp  cpu_usage  mem_used_mb  mem_free_mb
# 0  2026-04-18 10:38:15       34.9         1291         1164
# 1  2026-04-18 10:38:21       30.6         1288         1166
# 2  2026-04-18 10:38:26       27.7         1289         1165
# 3  2026-04-18 10:38:31       28.3         1282         1172
# 4  2026-04-18 10:38:37       28.3         1283         1170
